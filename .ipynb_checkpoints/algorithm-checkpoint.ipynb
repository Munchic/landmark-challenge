# %%
import pandas as pd

# %%
a = pd.read_csv('csv/train.csv')

# %%
b = a.sort_values(by="landmark_id")

# %%
b.head(100)
# Out:
#                        id                                                url  \
# 476443   d39eec4fd20f94fb  http://lh6.ggpht.com/-rqwSifo7yC8/TMNNi-PfgrI/...
# 657156   d48a522db8a92015  http://mw2.google.com/mw-panoramio/photos/medi...
# 989120   375d2a153bdca926  http://lh6.ggpht.com/-UqzFpnqE9bU/S_0u1RovfdI/...
# 1188288  89735d6bd3ed3a82  https://lh6.googleusercontent.com/-W7Z0zPkBKWw...
# 1001838  32f147ec11a8728f  https://lh3.googleusercontent.com/-ILPtK5tYVK0...
# 27969    c304be9cdb5a2455  https://lh5.googleusercontent.com/-wXX863wPAfA...
# 1001892  a92f2f29bab56bbc  http://mw2.google.com/mw-panoramio/photos/medi...
# 157998   85b7cd764448c45c  http://lh3.ggpht.com/-AV9EO-E43p8/SkzYjTNd3gI/...
# 853678   4e8ab93c1620e8a3  http://mw2.google.com/mw-panoramio/photos/medi...
# 381365   e9690aae80e21a23  https://lh5.googleusercontent.com/-7sSRpotfRYI...
# 351631   f4e5819b9ee83792  https://lh6.googleusercontent.com/-limoWy6SNU4...
# ...
