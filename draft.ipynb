# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os

# %%
a = pd.read_csv('csv/train.csv')
b = a.sort_values(by="landmark_id")

# %%
len(a)
# Out:
# 1225029

# %%
a.dropna(inplace=True)

# %%
len(a)
# Out:
# 1225029

# %%
a.mask(a.eq('None')).dropna(inplace=True)

# %%
os.listdir('dataset/train')[:10]
# Out:
# ['0ca5cc84b8ade91d.jpg',
#  '636f9893d0bb7010.jpg',
#  'ba60f576cbe02006.jpg',
#  'ad35fab11a0c8dc6.jpg',
#  'add9b816a0deac60.jpg',
#  '39b11a7c8f566330.jpg',
#  '1f9e4ed99c44a9b7.jpg',
#  '7832db98c87e6375.jpg',
#  '28ccf78ca2e4fe8b.jpg',
#  '87652df6dab3de92.jpg']

# %%
a = mpimg.imread('dataset/train-256/0ca5cc84b8ade91d.jpg')
b = mpimg.imread('dataset/train-256/add9b816a0deac60.jpg')

# %%
plt.imshow(a)
plt.show()

# %%
a
# Out:
# array([[[ 12,  21,  20],
#         [ 13,  18,  22],
#         [ 11,  15,  24],
#         ...,
#         [ 68, 113, 168],
#         [ 66, 111, 166],
#         [ 65, 110, 165]],
#
#        [[ 10,  19,  18],
#         [ 13,  18,  22],
#         [ 13,  17,  26],
#         ...,
#         [ 68, 113, 168],
#         [ 67, 112, 167],
#         [ 65, 110, 165]],
#
#        [[ 10,  19,  18],
#         [ 13,  18,  22],
#         [ 14,  18,  27],
#         ...,
#         [ 69, 114, 169],
#         [ 67, 112, 167],
#         [ 66, 111, 166]],
#
#        ...,
#
#        [[ 23,  15,  12],
#         [ 35,  27,  24],
#         [ 18,  10,   8],
#         ...,
#         [105, 135, 185],
#         [114, 142, 190],
#         [118, 146, 194]],
#
#        [[  9,   4,   1],
#         [ 23,  17,  17],
#         [ 24,  18,  18],
#         ...,
#         [106, 136, 186],
#         [113, 141, 189],
#         [115, 143, 191]],
#
#        [[ 14,  13,  11],
#         [ 13,   9,   8],
#         [ 16,  12,  11],
# ...

# %%
plt.imshow(b)
plt.show()

# %%
a = np.array(a, dtype=int)
b = np.array(b, dtype=int)
np.linalg.norm(a - b)
# Out:
# 43303.69090504873

# %%
None + '2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-a391a6d042b7> in <module>
# ----> 1 None + '2'
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
plt.hist(np.array([1, 2, 3, 4, 2, 5]))
# Out:
# (array([1., 0., 2., 0., 0., 1., 0., 1., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
np.array([1, 2, 3, 4, 2, 5])
# Out:
# array([1, 2, 3, 4, 2, 5])

# %%
radius = 5
std = 1
weights = list(map(lambda x: np.exp(-(x - 0) / (2*std**2)),
                  range(radius)))

# %%
weights
# Out:
# [1.0,
#  0.6065306597126334,
#  0.36787944117144233,
#  0.22313016014842982,
#  0.1353352832366127]
